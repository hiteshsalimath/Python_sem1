# %% [markdown]
# # $Inheritance$
#
# 1. Single inheritance is <br> ![image.png](attachment:image.png)<br>
# 2. Multilevel inheritance is <br> ![image-2.png](attachment:image-2.png)<br>
# 3. Multiple inheritance is <br> ![image-4.png](attachment:image-4.png) <br>
# 4. Hierarchial inheritance <br> ![image-3.png](attachment:image-3.png) <br>
# 5. Hybrid is combination of types <br> ![image-5.png](attachment:image-5.png)

# %%
def abc(x,y,z):
    a=10+x
    b=10+y
    c=10+z

o = abc(1,2,3)
print(o)
# Out:
# None
